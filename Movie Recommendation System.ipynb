# %%
import pandas as pd 
import numpy as np
df1=pd.read_csv('Datasets/tmdb_5000_credits.csv');
df2=pd.read_csv('Datasets/tmdb_5000_movies.csv');

# %% [markdown]
# ### Joining the 2 datasets about the column 'id'

# %%
df1.columns=['id','title','cas','crew']
df2=df2.merge(df1,on='id')

# %%
df2.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %% [markdown]
# # Demographic Filtering
#     -We can use the average ratings of the movie as a score to measure the likeness or to rate a movie.
#     DISADVANTAGE: It wont be fair because a movie with a rating of 9.2 average rating and only 4 votes cannot just be considered better than a movie with 7.8 as average but 40 votes.

# %% [markdown]
# ## IMDb's weighted rating
#  -Hence i chose to use the following weighted rating criteria(wr) given as:-
#      Weighted Rating(WR)=((v/(v+m))*R)+((m/(v+m))*C)
#      where,
#      -v is the number of votes for the movie.
#      -m is the number of votes required to be listed in the chart.
#      -R is the average rating of the movie.
#      -C is the mean vote across the whole report.

# %%
C=df2['vote_average'].mean(); # mean rating for all m
C
# Out:
# 6.092171559442011

# %%
# Using 90th percentile as cutoff.
m=df2['vote_count'].quantile(0.9)
m
# Out:
# 1838.4000000000015

# %%
q_movies=df2.copy().loc[df2['vote_count']>=m]
q_movies.shape
# Out:
# (481, 23)

# %% [markdown]
# #### This tells us that only 481 movies are there which qualify to be in this list.
#
# ## Defining a function to calculate the weighted rating of movies

# %%
def weighted_rating(x,m=m,C=C):
    v=x['vote_count']
    R=x['vote_average']
    # Applying the formula
    
    return (v/(v+m)*R)+(m/(m+v)*C)

# %%
#defining a new feature 'score' and calculating its value with ' weighted rating function'

q_movies['score']= q_movies.apply(weighted_rating,axis=1)

# %%
# Sorting the movies based on the score obtained 
q_movies = q_movies.sort_values('score', ascending=False)

# %%
#Printing the top 15 movies
q_movies.head(15)
# Out:
#          budget                                             genres  \
# 1881   25000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 662    63000000                      [{"id": 18, "name": "Drama"}]
# 65    185000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 3232    8000000  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 96    160000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 3337    6000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 95    165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 809    55000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 329    94000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 1990   18000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 262    93000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2912   11000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 1818   22000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# ...

# %%
q_movies.rename(columns={'title_x':'Title'},inplace=True)

# %% [markdown]
# ### Obtaining the first 15 most

# %%
ans=q_movies[['Title','vote_count','score']].head(15)
ans.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_5646ac08_c698_11ea_b52a_309c2391b6d4" ><thead>    <tr>        <th class="col_heading level0 col0" >Title</th>        <th class="col_heading level0 col1" >vote_count</th>        <th class="col_heading level0 col2" >score</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_5646ac08_c698_11ea_b52a_309c2391b6d4row0_col0" class="data row0 col0" >The Shawshank Redemption</td>
#                         <td id="T_5646ac08_c698_11ea_b52a_309c2391b6d4row0_col1" class="data row0 col1" >8205</td>
#                         <td id="T_5646ac08_c698_11ea_b52a_309c2391b6d4row0_col2" class="data row0 col2" >8.05926</td>
#             </tr>
#             <tr>
#                                 <td id="T_5646ac08_c698_11ea_b52a_309c2391b6d4row1_col0" class="data row1 col0" >Fight Club</td>
#                         <td id="T_5646ac08_c698_11ea_b52a_309c2391b6d4row1_col1" class="data row1 col1" >9413</td>
# ...
